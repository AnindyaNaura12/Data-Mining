# %% [markdown]
# <a href="https://colab.research.google.com/github/AnindyaNaura12/Data-Mining/blob/main/Modul5No3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mlxtend

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fb652295-d410-4726-ba40-7f48e1fe8ff3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fb652295-d410-4726-ba40-7f48e1fe8ff3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("Restaurant.csv")
df.columns = ["BOROUGH", "CUISINE", "GRADE"]
df.head()
# Out:
#        BOROUGH     CUISINE GRADE
# 0   MANHATTAN    American      C
# 1       BRONX     Chicken      C
# 2   MANHATTAN    American      A
# 3   MANHATTAN    American      A
# 4   MANHATTAN    American      C

# %%
transactions = df.values.tolist()
for t in transactions[:20]:
    print(t)
# Out:
# [' MANHATTAN ', ' American ', ' C']
# [' BRONX ', ' Chicken ', ' C']
# [' MANHATTAN ', ' American ', ' A']
# [' MANHATTAN ', ' American ', ' A']
# [' MANHATTAN ', ' American ', ' C']
# [' BRONX ', ' Pizza ', ' A']
# [' MANHATTAN ', ' Caribbean ', ' B']
# [' MANHATTAN ', ' Italian ', ' B']
# [' STATENISLAND ', ' Bakery ', ' A']
# [' BROOKLYN ', ' Creole ', ' A']
# [' MANHATTAN ', ' Chinese ', ' A']
# [' MANHATTAN ', ' American ', ' B']
# [' QUEENS ', ' American ', ' A']
# [' BRONX ', ' Pizza ', ' A']
# [' QUEENS ', ' Cafe/Coffee/Tea ', ' A']
# [' MANHATTAN ', ' Italian ', ' A']
# [' MANHATTAN ', ' Pizza ', ' B']
# [' QUEENS ', ' Japanese ', ' B']
# [' MANHATTAN ', ' Delicatessen ', ' B']
# [' QUEENS ', ' Pizza ', ' A']

# %%
te = TransactionEncoder()
te_data = te.fit(transactions).transform(transactions)

df_te = pd.DataFrame(te_data, columns=te.columns_)
df_te.head()
# Out:
#        A  Afghan   African   American   Armenian   Asian   Australian       B  \
# 0  False    False     False       True      False   False        False  False
# 1  False    False     False      False      False   False        False  False
# 2   True    False     False       True      False   False        False  False
# 3   True    False     False       True      False   False        False  False
# 4  False    False     False       True      False   False        False  False
#
#    BRONX   BROOKLYN   ...  Southwestern   Spanish   Steak   Tapas   Tex-Mex   \
# 0   False      False  ...          False     False   False   False     False
# 1    True      False  ...          False     False   False   False     False
# 2   False      False  ...          False     False   False   False     False
# 3   False      False  ...          False     False   False   False     False
# 4   False      False  ...          False     False   False   False     False
#
# ...

# %%
frequent_items = apriori(df_encoded, min_support=0.02, use_colnames=True)
frequent_items
# Out:
#      support                                           itemsets
# 0   0.513081                                               ( A)
# 1   0.239164                                       ( American )
# 2   0.283887                                               ( B)
# 3   0.095204                                          ( BRONX )
# 4   0.232744                                       ( BROOKLYN )
# 5   0.032693                                         ( Bakery )
# 6   0.156340                                               ( C)
# 7   0.032120                                ( Cafe/Coffee/Tea )
# 8   0.030412                                      ( Caribbean )
# 9   0.118038                                        ( Chinese )
# 10  0.047672                                        ( Italian )
# 11  0.032054                                       ( Japanese )
# 12  0.051895  ( Latin (Cuban Dominican Puerto Rican South & ...
# 13  0.412647                                      ( MANHATTAN )
# ...

# %%
rules = association_rules(frequent_items, metric="confidence", min_threshold=0.2)
rules
# Out:
#                                           antecedents        consequents  \
# 0                                                ( A)       ( American )
# 1                                        ( American )               ( A)
# 2                                           ( BRONX )               ( A)
# 3                                                ( A)       ( BROOKLYN )
# 4                                        ( BROOKLYN )               ( A)
# 5                                 ( Cafe/Coffee/Tea )               ( A)
# 6                                         ( Chinese )               ( A)
# 7                                         ( Italian )               ( A)
# 8   ( Latin (Cuban Dominican Puerto Rican South & ...               ( A)
# 9                                                ( A)      ( MANHATTAN )
# 10                                      ( MANHATTAN )               ( A)
# 11                                          ( Pizza )               ( A)
# ...

# %%
rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']]
# Out:
#                                           antecedents        consequents  \
# 0                                                ( A)       ( American )
# 1                                        ( American )               ( A)
# 2                                           ( BRONX )               ( A)
# 3                                                ( A)       ( BROOKLYN )
# 4                                        ( BROOKLYN )               ( A)
# 5                                 ( Cafe/Coffee/Tea )               ( A)
# 6                                         ( Chinese )               ( A)
# 7                                         ( Italian )               ( A)
# 8   ( Latin (Cuban Dominican Puerto Rican South & ...               ( A)
# 9                                                ( A)      ( MANHATTAN )
# 10                                      ( MANHATTAN )               ( A)
# 11                                          ( Pizza )               ( A)
# ...

# %%
for _, row in rules.iterrows():
    antecedent = ', '.join(list(row['antecedents']))
    consequent = ', '.join(list(row['consequents']))

    print(f"Pelanggan yang membeli {antecedent} cenderung juga membeli {consequent}")
# Out:
# Pelanggan yang membeli  A cenderung juga membeli  American
# Pelanggan yang membeli  American  cenderung juga membeli  A
# Pelanggan yang membeli  BRONX  cenderung juga membeli  A
# Pelanggan yang membeli  A cenderung juga membeli  BROOKLYN
# Pelanggan yang membeli  BROOKLYN  cenderung juga membeli  A
# Pelanggan yang membeli  Cafe/Coffee/Tea  cenderung juga membeli  A
# Pelanggan yang membeli  Chinese  cenderung juga membeli  A
# Pelanggan yang membeli  Italian  cenderung juga membeli  A
# Pelanggan yang membeli  Latin (Cuban Dominican Puerto Rican South & Central American)  cenderung juga membeli  A
# Pelanggan yang membeli  A cenderung juga membeli  MANHATTAN
# Pelanggan yang membeli  MANHATTAN  cenderung juga membeli  A
# Pelanggan yang membeli  Pizza  cenderung juga membeli  A
# Pelanggan yang membeli  A cenderung juga membeli  QUEENS
# Pelanggan yang membeli  QUEENS  cenderung juga membeli  A
# Pelanggan yang membeli  STATENISLAND  cenderung juga membeli  A
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(rules['support'], rules['confidence'])
plt.xlabel('Support')
plt.ylabel('Confidence')
plt.show()
